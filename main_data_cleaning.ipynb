# %%
import pandas as pd
pd.__version__

# General libraries.
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import altair as alt
import os

# %%
# main_path = "/Users/neilbhatia/Dropbox/mids/Courses/w209_dataviz/final_project_follow_the_money/data"
main_path = "D:\\Dropbox\\mids\\Courses\\w209_dataviz\\final_project_follow_the_money\\data"

# %% [markdown]
# # Contributions from Committee to Candidates

# %%
contributions_committee_to_candidate_columns = pd.read_csv(os.path.join(main_path, "contributions_from_committees_to_cand","pas2_header_file.csv"))
contributions_committee_to_candidate_columns
# Out:
# Empty DataFrame
# Columns: [CMTE_ID, AMNDT_IND, RPT_TP, TRANSACTION_PGI, IMAGE_NUM, TRANSACTION_TP, ENTITY_TP, NAME, CITY, STATE, ZIP_CODE, EMPLOYER, OCCUPATION, TRANSACTION_DT, TRANSACTION_AMT, OTHER_ID, CAND_ID, TRAN_ID, FILE_NUM, MEMO_CD, MEMO_TEXT, SUB_ID]
# Index: []
#
# [0 rows x 22 columns]

# %%
contr_c2c_df = pd.read_csv(os.path.join(main_path, "contributions_from_committees_to_cand","itpas2.txt"), sep="|", header=None, names = contributions_committee_to_candidate_columns.columns)
contr_c2c_df
# Out:
# C:\Users\covem\AppData\Local\Temp\ipykernel_12900\396683436.py:1: DtypeWarning: Columns (10,11,12,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   contr_c2c_df = pd.read_csv(os.path.join(main_path, "contributions_from_committees_to_cand","itpas2.txt"), sep="|", header=None, names = contributions_committee_to_candidate_columns.columns)
#           CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI           IMAGE_NUM  \
# 0       C00761528         N    30R           R2021  202101279413461164
# 1       C00761528         N    30R           R2021  202101279413461164
# 2       C00710780         T    TER           G2020  202101279413440230
# 3       C00710780         T    TER           G2020  202101279413440227
# 4       C00710780         T    TER           G2020  202101279413440227
# ...           ...       ...    ...             ...                 ...
# 410509  C00125732         N     M6           P2022  202206169514918546
# 410510  C00010983         N     M6           P2022  202206169514918381
# 410511  C00010983         N     M6           P2022  202206169514918381
# 410512  C00010983         N     M6           P2022  202206169514918381
# 410513  C00010983         N     M6           P2022  202206169514918382
#
#        TRANSACTION_TP ENTITY_TP                             NAME        CITY  \
# 0                 24K       CCM     GEORGIANS FOR KELLY LOEFFLER     ATLANTA
# 1                 24K       CCM                PERDUE FOR SENATE     ATLANTA
# 2                 24K       CCM              WARNOCK FOR GEORGIA     DECATUR
# 3                 24K       CCM     JAIME HARRISON FOR US SENATE    COLUMBIA
# 4                 24K       CCM            JON OSSOFF FOR SENATE     ATLANTA
# ...               ...       ...                              ...         ...
# 410509            24K       CCM          MIKE FLOOD FOR CONGRESS     LINCOLN
# 410510            24K       CCM  BRIAN FITZPATRICK FOR ALL OF US   LANGHORNE
# 410511            24K       CCM          CARTWRIGHT FOR CONGRESS    SCRANTON
# 410512            24K       CCM          MIKE KELLY FOR CONGRESS     LYNDORA
# 410513            24K       CCM        TERRI SEWELL FOR CONGRESS  BIRMINGHAM
#
#        STATE  ... OCCUPATION TRANSACTION_DT TRANSACTION_AMT   OTHER_ID  \
# 0         GA  ...        NaN     12242020.0            2000  C00729608
# 1         GA  ...        NaN     12242020.0            2000  C00547570
# 2         GA  ...        NaN     11172020.0            1500  C00736876
# 3         SC  ...        NaN     10272020.0            1500  C00696153
# 4         GA  ...        NaN     11172020.0            1500  C00718866
# ...      ...  ...        ...            ...             ...        ...
# 410509    NE  ...        NaN      5232022.0            2500  C00801241
# 410510    PA  ...        NaN      5122022.0            1500  C00607416
# 410511    PA  ...        NaN      5132022.0            1000  C00509968
# 410512    PA  ...        NaN      5132022.0            1000  C00474189
# 410513    AL  ...        NaN      5232022.0            1000  C00458976
#
#           CAND_ID               TRAN_ID FILE_NUM MEMO_CD  MEMO_TEXT  \
# 0       S0GA00526             SB23.4137  1492056     NaN        NaN
# 1       S4GA11285             SB23.4140  1492056     NaN        NaN
# 2       S0GA00559             SB21.4225  1491682     NaN        NaN
# 3       S0SC00289             SB21.4219  1491682     NaN        NaN
# 4       S8GA00180             SB21.4222  1491682     NaN        NaN
# ...           ...                   ...      ...     ...        ...
# 410509  H2NE01118  B75034DF9A57D45CAA4D  1602477     NaN        NaN
# 410510  H6PA08277   D4C0EB0FBE9ACBC6358  1602471     NaN        NaN
# 410511  H2PA17079   4C16FA35EBDB383566D  1602471     NaN        NaN
# 410512  H0PA03271   C71C5E31C74B2FC5200  1602471     NaN        NaN
# 410513  H0AL07086   7402AE96E4C2F94D055  1602471     NaN        NaN
#
#                      SUB_ID
# 0       4012920212139007940
# 1       4012920212139007941
# 2       4020320212018112012
# 3       4020320212018112003
# 4       4020320212018112004
# ...                     ...
# 410509  4061720221530344955
# 410510  4061720221530344272
# 410511  4061720221530344273
# 410512  4061720221530344274
# 410513  4061720221530344275
#
# [410514 rows x 22 columns]

# %%
contr_c2c_total = contr_c2c_df.groupby(['CMTE_ID', 'NAME', 'CITY', 'STATE', 'CAND_ID'], as_index=False).agg(
    TRANSACTION_AMT_sum=('TRANSACTION_AMT', np.sum)
)

contr_c2c_total
# Out:
#          CMTE_ID                        NAME         CITY STATE    CAND_ID  \
# 0      C00000422   ADRIAN SMITH FOR CONGRESS  SCOTTSBLUFF    NE  H6NE03115
# 1      C00000422     ALMA ADAMS FOR CONGRESS    CHARLOTTE    NC  H4NC12100
# 2      C00000422    ANGIE CRAIG FOR CONGRESS        EAGAN    MN  H6MN02131
# 3      C00000422     ANNA ESHOO FOR CONGRESS   SACRAMENTO    CA  H8CA12098
# 4      C00000422  ASHLEY HINSON FOR CONGRESS       MARION    IA  H0IA01174
# ...          ...                         ...          ...   ...        ...
# 93550  C90021304         QUINTANILLA, BLANCA     EDINBURG    TX  H2TX15203
# 93551  C90021304                ROCHA, SARAH     EDINBURG    TX  H2TX15203
# 93552  C90021304              RUBIO, ROGELIO  LOS FRESNOS    TX  H2TX15203
# 93553  C90021304             RUIZ, MARGARITA     EDINBURG    TX  H2TX15203
# 93554  C90021304               WILDFIRE MAIL      METHEUN    MA  H2TX15203
#
#        TRANSACTION_AMT_sum
# 0                     1000
# 1                     1000
# 2                     2000
# 3                     2000
# 4                     1000
# ...                    ...
# 93550                 5000
# 93551                 3500
# 93552                 4000
# 93553                 3500
# 93554                14431
#
# [93555 rows x 6 columns]

# %%
contr_c2c_df.head(100).to_csv("contr_c2c_df.csv",index=False)

# %%
transaction_type_dict = {'10': 'Contribution to Independent Expenditure-Only Committees (Super PACs), Political Committees with non-contribution accounts (Hybrid PACs) and nonfederal party "soft money" accounts (1991-2002) from a person (individual, partnership, limited liability company, corporation, labor organization, or any other organization or group of persons)',
 '10J': "Memo - Recipient committee's percentage of nonfederal receipt from a person (individual, partnership, limited liability company, corporation, labor organization, or any other organization or group of persons)",
 '11': 'Native American Tribe contribution',
 '11J': "Memo - Recipient committee's percentage of contribution from Native American Tribe given to joint fundraising committee",
 '12': 'Nonfederal other receipt - Levin Account (Line 2)',
 '13': 'Inaugural donation accepted',
 '15': 'Contribution to political committees (other than Super PACs and Hybrid PACs) from an individual, partnership or limited liability company',
 '15C': 'Contribution from candidate',
 '15E': 'Earmarked contributions to political committees (other than Super PACs and Hybrid PACs) from an individual, partnership or limited liability company',
 '15F': 'Loans forgiven by candidate',
 '15I': "Earmarked contribution from an individual, partnership or limited liability company received by intermediary committee and passed on in the form of contributor's check (intermediary in)",
 '15J': "Memo - Recipient committee's percentage of contribution from an individual, partnership or limited liability company given to joint fundraising committee",
 '15T': "Earmarked contribution from an individual, partnership or limited liability company received by intermediary committee and entered into intermediary's treasury (intermediary treasury in)",
 '15Z': 'In-kind contribution received from registered filer',
 '16C': 'Loan received from the candidate',
 '16F': 'Loan received from bank',
 '16G': 'Loan from individual',
 '16H': 'Loan from registered filers',
 '16J': 'Loan repayment from individual',
 '16K': 'Loan repayment from from registered filer',
 '16L': 'Loan repayment received from unregistered entity',
 '16R': 'Loan received from registered filers',
 '16U': 'Loan received from unregistered entity',
 '17R': 'Contribution refund received from registered entity',
 '17U': 'Refund/Rebate/Return received from unregistered entity',
 '17Y': 'Refund/Rebate/Return from individual or corporation',
 '17Z': 'Refund/Rebate/Return from candidate or committee',
 '18G': 'Transfer in from affiliated committee',
 '18H': 'Honorarium received',
 '18J': "Memo - Recipient committee's percentage of contribution from a registered committee given to joint fundraising committee",
 '18K': 'Contribution received from registered filer',
 '18L': 'Bundled contribution',
 '18U': 'Contribution received from unregistered committee',
 '19': 'Electioneering communication donation received',
 '19J': "Memo - Recipient committee's percentage of Electioneering Communication donation given to joint fundraising committee",
 '20': 'Nonfederal disbursement - nonfederal party "soft money" accounts (1991-2002)',
 '20A': 'Nonfederal disbursement - Levin Account (Line 4A) Voter Registration',
 '20B': 'Nonfederal Disbursement - Levin Account (Line 4B) Voter Identification',
 '20C': 'Loan repayment made to candidate',
 '20D': 'Nonfederal disbursement - Levin Account (Line 4D) Generic Campaign',
 '20F': 'Loan repayment made to banks',
 '20G': 'Loan repayment made to individual',
 '20R': 'Loan repayment made to registered filer',
 '20V': 'Nonfederal disbursement - Levin Account (Line 4C) Get Out The Vote',
 '20Y': 'Nonfederal refund',
 '21Y': 'Native American Tribe refund',
 '22G': 'Loan to individual',
 '22H': 'Loan to candidate or committee',
 '22J': 'Loan repayment to individual',
 '22K': 'Loan repayment to candidate or committee',
 '22L': 'Loan repayment to bank',
 '22R': 'Contribution refund to unregistered entity',
 '22U': 'Loan repaid to unregistered entity',
 '22X': 'Loan made to unregistered entity',
 '22Y': 'Contribution refund to an individual, partnership or limited liability company',
 '22Z': 'Contribution refund to candidate or committee',
 '23Y': 'Inaugural donation refund',
 '24A': 'Independent expenditure opposing election of candidate',
 '24C': 'Coordinated party expenditure',
 '24E': 'Independent expenditure advocating election of candidate',
 '24F': 'Communication cost for candidate (only for Form 7 filer)',
 '24G': 'Transfer out to affiliated committee',
 '24H': 'Honorarium to candidate',
 '24I': "Earmarked contributor's check passed on by intermediary committee to intended recipient (intermediary out)",
 '24K': 'Contribution made to nonaffiliated committee',
 '24N': 'Communication cost against candidate (only for Form 7 filer)',
 '24P': 'Contribution made to possible federal candidate including in-kind contributions',
 '24R': 'Election recount disbursement',
 '24T': "Earmarked contribution passed to intended recipient from intermediary's treasury (treasury out)",
 '24U': 'Contribution made to unregistered entity',
 '24Z': 'In-kind contribution made to registered filer',
 '28L': 'Refund of bundled contribution',
 '29': 'Electioneering Communication disbursement or obligation',
 '30': 'Convention Account receipt from an individual, partnership or limited liability company',
 '30T': 'Convention Account receipt from Native American Tribe',
 '30K': 'Convention Account receipt from registered filer',
 '30G': 'Convention Account - transfer in from affiliated committee',
 '30J': "Convention Account - Memo - Recipient committee's percentage of contributions from an individual, partnership or limited liability company given to joint fundraising committee",
 '30F': "Convention Account - Memo - Recipient committee's percentage of contributions from a registered committee given to joint fundraising committee",
 '31': 'Headquarters Account receipt from an individual, partnership or limited liability company',
 '31T': 'Headquarters Account receipt from Native American Tribe',
 '31K': 'Headquarters Account receipt from registered filer',
 '31G': 'Headquarters Account - transfer in from affiliated committee',
 '31J': "Headquarters Account - Memo - Recipient committee's percentage of contributions from an individual, partnership or limited liability company given to joint fundraising committee",
 '31F': "Headquarters Account - Memo - Recipient committee's percentage of contributions from a registered committee given to joint fundraising committee",
 '32': 'Recount Account receipt from an individual, partnership or limited liability company',
 '32T': 'Recount Account receipt from Native American Tribe',
 '32K': 'Recount Account receipt from registered filer',
 '32G': 'Recount Account - transfer in from affiliated committee',
 '32J': "Recount Account - Memo - Recipient committee's percentage of contributions from an individual, partnership or limited liability company given to joint fundraising committee",
 '32F': "Recount Account - Memo - Recipient committee's percentage of contributions from a registered committee given to joint fundraising committee",
 '40': 'Convention Account disbursement',
 '40Y': 'Convention Account refund to an individual, partnership or limited liability company',
 '40T': 'Convention Account refund to Native American Tribe',
 '40Z': 'Convention Account refund to registered filer',
 '41': 'Headquarters Account disbursement',
 '41Y': 'Headquarters Account refund to an individual, partnership or limited liability company',
 '41T': 'Headquarters Account refund to Native American Tribe',
 '41Z': 'Headquarters Account refund to registered filer',
 '42': 'Recount Account disbursement',
 '42Y': 'Recount Account refund to an individual, partnership or limited liability company',
 '42T': 'Recount Account refund to Native American Tribe',
 '42Z': 'Recount Account refund to registered filer'}

# %% [markdown]
# # Candidates Master
#
# The candidate master file contains one record for each candidate who has either registered with the Federal Election Commission or appeared on a ballot list prepared by a state elections office.

# %%
"candidate_master"

os.path.join(main_path, "candidate_master","cn_header_file.csv")

candidate_master_columns = pd.read_csv(os.path.join(main_path, "candidate_master","cn_header_file.csv"))
candidate_master_columns

candidate_master_df = pd.read_csv(os.path.join(main_path, "candidate_master","cn.txt"), sep="|", header=None, names = candidate_master_columns.columns)
candidate_master_df.head(100).to_csv("candidates_master.csv",index=False)

# %% [markdown]
# # Merging the two

# %%
# contr_c2c_total_JOINED1 = contr_c2c_df.merge(candidate_master_df, on='CAND_ID')
# contr_c2c_total_JOINED1

contr_c2c_total_JOINED1 = pd.merge(contr_c2c_df,candidate_master_df,how='left',on='CAND_ID')
contr_c2c_total_JOINED1
# Out:
#           CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI           IMAGE_NUM  \
# 0       C00761528         N    30R           R2021  202101279413461164
# 1       C00761528         N    30R           R2021  202101279413461164
# 2       C00710780         T    TER           G2020  202101279413440230
# 3       C00710780         T    TER           G2020  202101279413440227
# 4       C00710780         T    TER           G2020  202101279413440227
# ...           ...       ...    ...             ...                 ...
# 410509  C00125732         N     M6           P2022  202206169514918546
# 410510  C00010983         N     M6           P2022  202206169514918381
# 410511  C00010983         N     M6           P2022  202206169514918381
# 410512  C00010983         N     M6           P2022  202206169514918381
# 410513  C00010983         N     M6           P2022  202206169514918382
#
#        TRANSACTION_TP ENTITY_TP                             NAME        CITY  \
# 0                 24K       CCM     GEORGIANS FOR KELLY LOEFFLER     ATLANTA
# 1                 24K       CCM                PERDUE FOR SENATE     ATLANTA
# 2                 24K       CCM              WARNOCK FOR GEORGIA     DECATUR
# 3                 24K       CCM     JAIME HARRISON FOR US SENATE    COLUMBIA
# 4                 24K       CCM            JON OSSOFF FOR SENATE     ATLANTA
# ...               ...       ...                              ...         ...
# 410509            24K       CCM          MIKE FLOOD FOR CONGRESS     LINCOLN
# 410510            24K       CCM  BRIAN FITZPATRICK FOR ALL OF US   LANGHORNE
# 410511            24K       CCM          CARTWRIGHT FOR CONGRESS    SCRANTON
# 410512            24K       CCM          MIKE KELLY FOR CONGRESS     LYNDORA
# 410513            24K       CCM        TERRI SEWELL FOR CONGRESS  BIRMINGHAM
#
#        STATE  ... CAND_OFFICE CAND_OFFICE_DISTRICT CAND_ICI  CAND_STATUS  \
# 0         GA  ...           S                  0.0        I            P
# 1         GA  ...           S                  0.0        C            N
# 2         GA  ...           S                  0.0        I            C
# 3         SC  ...           S                  0.0        C            P
# 4         GA  ...           S                  0.0        I            C
# ...      ...  ...         ...                  ...      ...          ...
# 410509    NE  ...           H                  1.0        C            C
# 410510    PA  ...           H                  1.0        I            C
# 410511    PA  ...           H                  8.0        I            C
# 410512    PA  ...           H                 16.0        I            C
# 410513    AL  ...           H                  7.0        I            C
#
#          CAND_PCC        CAND_ST1 CAND_ST2   CAND_CITY  CAND_ST CAND_ZIP
# 0       C00729608    PO BOX 11623      NaN     ATLANTA       GA  30355.0
# 1       C00547570    PO BOX 12077      NaN     ATLANTA       GA  30355.0
# 2       C00736876    PO BOX 52227      NaN     ATLANTA       GA  30355.0
# 3       C00696153     PO BOX 1767      NaN    COLUMBIA       SC  29202.0
# 4       C00718866   PO BOX 450326      NaN     ATLANTA       GA  31145.0
# ...           ...             ...      ...         ...      ...      ...
# 410509  C00801241    PO BOX 81041      NaN     LINCOLN       NE  68501.0
# 410510  C00607416      PO BOX 939      NaN   LANGHORNE       PA  19047.0
# 410511  C00509968      PO BOX 414      NaN    SCRANTON       PA  18501.0
# 410512  C00474189  239 W PEARL ST      NaN      BUTLER       PA  16001.0
# 410513  C00458976     PO BOX 1964      NaN  BIRMINGHAM       AL  35201.0
#
# [410514 rows x 36 columns]

# %%
contr_c2c_total_JOINED1.head(100).to_csv('contrc2c.csv',index=False)

# %% [markdown]
# # Now lets try and merge in committee master

# %%
"candidate_master"

os.path.join(main_path, "committee_master","cm_header_file.csv")

committee_master_columns = pd.read_csv(os.path.join(main_path, "committee_master","cm_header_file.csv"))
committee_master_columns

committee_master_df = pd.read_csv(os.path.join(main_path, "committee_master","cm.txt"), sep="|", header=None, names = committee_master_columns.columns)

#COMMITTEE HAS A CAND_ID COLUMN
#When a committee has a committee type designation of H, S, or P, the candidate's identification number will be entered in this field.	

#RENAME TO SOMETHING ELSE
committee_master_df = committee_master_df.rename(columns={'CAND_ID':'CMTE_CAND_ID'})

committee_master_df.head(100).to_csv("committee_master.csv",index=False)

committee_master_df
# Out:
#          CMTE_ID                                            CMTE_NM  \
# 0      C00000059                 HALLMARK CARDS, INC. PAC (HALLPAC)
# 1      C00000422  AMERICAN MEDICAL ASSOCIATION POLITICAL ACTION ...
# 2      C00000489               D R I V E POLITICAL FUND CHAPTER 886
# 3      C00000547  KANSAS MEDICAL SOCIETY POLITICAL ACTION COMMITTEE
# 4      C00000729  AMERICAN DENTAL ASSOCIATION POLITICAL ACTION C...
# ...          ...                                                ...
# 18545  C90021346  INTERGALACTICAL GLOBAL AND LOCAL RELIGIOUS GOV...
# 18546  C90021353                    OPPORTUNITY FOR ALL ACTION FUND
# 18547  C90021361                            CHARTER SCHOOLS NOW PAC
# 18548  C90021379                ONSLOW COUNTY REPUBLICAN MEN'S CLUB
# 18549  C99002396                AMERICAN POLITICAL ACTION COMMITTEE
#
#                       TRES_NM                  CMTE_ST1    CMTE_ST2  \
# 0           KLEIN, CASSIE MS.         2501 MCGEE, MD853         NaN
# 1           WALKER, KEVIN MR.  25 MASSACHUSETTS AVE, NW   SUITE 600
# 2               JERRY SIMS JR               3528 W RENO         NaN
# 3             JERRY SLAUGHTER           623 SW 10TH AVE         NaN
# 4      FAIR, JULIAN H DR. III      1111 14TH STREET, NW  SUITE 1100
# ...                       ...                       ...         ...
# 18545                     NaN       707-17TH ST APT 709         NaN
# 18546                     NaN       1032 15TH STREET NW   SUITE 247
# 18547                     NaN             P.O. BOX 1176         NaN
# 18548                     NaN       109 CORMORANT DRIVE         NaN
# 18549           VERSNEL, J.H.               PO BOX 1682         NaN
#
#            CMTE_CITY CMTE_ST   CMTE_ZIP CMTE_DSGN CMTE_TP  \
# 0        KANSAS CITY      MO      64108         B       Q
# 1         WASHINGTON      DC  200017400         B       Q
# 2      OKLAHOMA CITY      OK      73107         U       N
# 3             TOPEKA      KS  666121627         U       Q
# 4         WASHINGTON      DC  200055627         B       Q
# ...              ...     ...        ...       ...     ...
# 18545      SAN DIEGO      CA      92101         U       I
# 18546     WASHINGTON      DC      20005         U       I
# 18547         AUSTIN      TX  787671176         U       I
# 18548      SWANSBORO      NC      28584         U       I
# 18549       BELLEVUE      WA      98009         U       Q
#
#       CMTE_PTY_AFFILIATION CMTE_FILING_FREQ ORG_TP        CONNECTED_ORG_NM  \
# 0                      UNK                M      C    HALLMARK CARDS, INC.
# 1                      NaN                M    NaN     ALABAMA MEDICAL PAC
# 2                      NaN                Q      L                     NaN
# 3                      UNK                Q      M  KANSAS MEDICAL SOCIETY
# 4                      UNK                M      M                     NaN
# ...                    ...              ...    ...                     ...
# 18545                  NaN                Q    NaN                     NaN
# 18546                  NaN                Q    NaN                     NaN
# 18547                  NaN                Q    NaN                     NaN
# 18548                  NaN                Q    NaN                     NaN
# 18549                  NaN                Q    NaN                    NONE
#
#       CMTE_CAND_ID
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 18545          NaN
# 18546          NaN
# 18547          NaN
# 18548          NaN
# 18549          NaN
#
# [18550 rows x 15 columns]

# %% [markdown]
# # Now we make the final merge
#
#
# # This is the combination of
#
#
# * Committee Master
#     * gives you all the names of the committee
#     * gives you CONNECTED_ORG_NM, which is very important and tells you the organizations connected to the commitee
# * Candidate Master
#     * Links the candidate ID to the candidate name and election year and state and city
#
# * contributions_from_committees_to_cand
#     * this tells you the individual transactions between committees and candidates

# %%
# contr_c2c_total_JOINED2 = contr_c2c_total_JOINED1.merge(committee_master_df, on='CMTE_ID')

contr_c2c_total_JOINED2 = pd.merge(contr_c2c_total_JOINED1,committee_master_df,how='left',on='CMTE_ID')
contr_c2c_total_JOINED2
# Out:
#           CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI           IMAGE_NUM  \
# 0       C00761528         N    30R           R2021  202101279413461164
# 1       C00761528         N    30R           R2021  202101279413461164
# 2       C00710780         T    TER           G2020  202101279413440230
# 3       C00710780         T    TER           G2020  202101279413440227
# 4       C00710780         T    TER           G2020  202101279413440227
# ...           ...       ...    ...             ...                 ...
# 410509  C00125732         N     M6           P2022  202206169514918546
# 410510  C00010983         N     M6           P2022  202206169514918381
# 410511  C00010983         N     M6           P2022  202206169514918381
# 410512  C00010983         N     M6           P2022  202206169514918381
# 410513  C00010983         N     M6           P2022  202206169514918382
#
#        TRANSACTION_TP ENTITY_TP                             NAME        CITY  \
# 0                 24K       CCM     GEORGIANS FOR KELLY LOEFFLER     ATLANTA
# 1                 24K       CCM                PERDUE FOR SENATE     ATLANTA
# 2                 24K       CCM              WARNOCK FOR GEORGIA     DECATUR
# 3                 24K       CCM     JAIME HARRISON FOR US SENATE    COLUMBIA
# 4                 24K       CCM            JON OSSOFF FOR SENATE     ATLANTA
# ...               ...       ...                              ...         ...
# 410509            24K       CCM          MIKE FLOOD FOR CONGRESS     LINCOLN
# 410510            24K       CCM  BRIAN FITZPATRICK FOR ALL OF US   LANGHORNE
# 410511            24K       CCM          CARTWRIGHT FOR CONGRESS    SCRANTON
# 410512            24K       CCM          MIKE KELLY FOR CONGRESS     LYNDORA
# 410513            24K       CCM        TERRI SEWELL FOR CONGRESS  BIRMINGHAM
#
#        STATE  ...   CMTE_CITY CMTE_ST   CMTE_ZIP  CMTE_DSGN  CMTE_TP  \
# 0         GA  ...  ALEXANDRIA      VA      22314          D        N
# 1         GA  ...  ALEXANDRIA      VA      22314          D        N
# 2         GA  ...     MISSION      KS      66202          P        S
# 3         SC  ...     MISSION      KS      66202          P        S
# 4         GA  ...     MISSION      KS      66202          P        S
# ...      ...  ...         ...     ...        ...        ...      ...
# 410509    NE  ...  RAPID CITY      SD  577091400          B        Q
# 410510    PA  ...  WASHINGTON      DC      20005          B        Q
# 410511    PA  ...  WASHINGTON      DC      20005          B        Q
# 410512    PA  ...  WASHINGTON      DC      20005          B        Q
# 410513    AL  ...  WASHINGTON      DC      20005          B        Q
#
#        CMTE_PTY_AFFILIATION CMTE_FILING_FREQ ORG_TP  CONNECTED_ORG_NM  \
# 0                       NaN                Q    NaN             BENTZ
# 1                       NaN                Q    NaN             BENTZ
# 2                       DEM                T    NaN               NaN
# 3                       DEM                T    NaN               NaN
# 4                       DEM                T    NaN               NaN
# ...                     ...              ...    ...               ...
# 410509                  NaN                M      C               NaN
# 410510                  NaN                M      C               NaN
# 410511                  NaN                M      C               NaN
# 410512                  NaN                M      C               NaN
# 410513                  NaN                M      C               NaN
#
#        CMTE_CAND_ID
# 0               NaN
# 1               NaN
# 2         S0KS00232
# 3         S0KS00232
# 4         S0KS00232
# ...             ...
# 410509          NaN
# 410510          NaN
# 410511          NaN
# 410512          NaN
# 410513          NaN
#
# [410514 rows x 50 columns]

# %%
contr_c2c_total_JOINED2.head(100).to_csv('final_merge.csv',index=False)

# %% [markdown]
# # Now commencing work on the final df

# %%
committee_id_and_names_only_df = contr_c2c_total_JOINED2[['CMTE_ID','CMTE_NM']].drop_duplicates()
committee_id_and_names_only_df
# Out:
#           CMTE_ID                                            CMTE_NM
# 0       C00761528                                OREGON FRONTIER PAC
# 2       C00710780                            GRISSOM FOR U.S. SENATE
# 6       C00364471    INGRAM BARGE COMPANY POLITICAL ACTION COMMITTEE
# 8       C00760454                          FPC AMERICAN VICTORY FUND
# 32      C00760025            MUSLIMS OF UNITED STATES OF AMERICA PAC
# ...           ...                                                ...
# 408697  C00035600                              IOWA DEMOCRATIC PARTY
# 408706  C00583229  PERMOBIL, INC. FEDERAL POLITICAL ACTION COMMITTEE
# 409306  C00468405                           ROBERT HURT FOR CONGRESS
# 409630  C00185694           ASSURANT INC. POLITICAL ACTION COMMITTEE
# 409892  C00736041  PEOPLE FOR BETTER GOVERNMENT COMMITTEE OF THE ...
#
# [4051 rows x 2 columns]

# %%
# TRANSACTION_TP = Transaction types
# SUB_ID = FEC Record Indicator
# NAME = Contributor/lender/transfer Name	
# ENTITY_TP = 
# CAN = Candidate
# CCM = Candidate Committee
# COM = Committee
# IND = Individual (a person)
# ORG = Organization (not a committee and not a person)
# PAC = Political Action Committee
# PTY = Party Organization
#TRES_NM = The officially registered treasurer for the committee.	

# CMTE_DSGN = A = Authorized by a candidate
# B = Lobbyist/Registrant PAC
# D = Leadership PAC
# J = Joint fundraiser
# P = Principal campaign committee of a candidate
# U = Unauthorized

# CAND_OFFICE = H, P, or S. House President and Senate

most_important_cols_df = contr_c2c_total_JOINED2[['SUB_ID','TRANSACTION_DT','AMNDT_IND','TRANSACTION_TP','CMTE_ID','CMTE_NM','CMTE_DSGN','CMTE_TP', 'CONNECTED_ORG_NM','ENTITY_TP','TRANSACTION_AMT','NAME','CAND_ID','CAND_NAME','CAND_ELECTION_YR','CAND_OFFICE','CAND_OFFICE_ST','CAND_OFFICE_DISTRICT','CAND_CITY','CAND_ZIP','CAND_PTY_AFFILIATION']].drop_duplicates()

# %%
# Need to map the following cols:
#AMNDT_IND
#TRANSACTION_TP
#CMTE_DSGN
#CMTE_TP

# %%
columns_renamed_dict = {'SUB_ID': 'fec_record_number',
 'TRANSACTION_DT': 'transaction_date',
 'AMNDT_IND': 'amendment_indicator_code',
 'TRANSACTION_TP': 'transaction_type_code',
 'CMTE_ID': 'committee_id',
 'CMTE_NM': 'comittee_name',
 'CMTE_DSGN': 'committee_designation_code',
 'CMTE_TP': 'committee_type_code',
 'CONNECTED_ORG_NM': 'connected_organization_name',
 'ENTITY_TP': 'committee_entity_type',
 'TRANSACTION_AMT': 'transaction_amount',
 'NAME': 'campaign_receipt_name',
 'CAND_ID': 'candidate_id',
 'CAND_NAME': 'candidate_name',
 'CAND_ELECTION_YR': 'candidate_election_year',
 'CAND_OFFICE': 'candidate_election_office_type',
 'CAND_OFFICE_ST': 'candidate_state',
 'CAND_OFFICE_DISTRICT': 'candidate_district',
 'CAND_CITY': 'candidate_city',
 'CAND_ZIP': 'candidate_zip',
 'CAND_PTY_AFFILIATION': 'candidate_party'}

# %%
most_important_cols_df = most_important_cols_df.rename(columns = columns_renamed_dict)
most_important_cols_df
# Out:
#           fec_record_number  transaction_date amendment_indicator_code  \
# 0       4012920212139007940        12242020.0                        N
# 1       4012920212139007941        12242020.0                        N
# 2       4020320212018112012        11172020.0                        T
# 3       4020320212018112003        10272020.0                        T
# 4       4020320212018112004        11172020.0                        T
# ...                     ...               ...                      ...
# 410509  4061720221530344955         5232022.0                        N
# 410510  4061720221530344272         5122022.0                        N
# 410511  4061720221530344273         5132022.0                        N
# 410512  4061720221530344274         5132022.0                        N
# 410513  4061720221530344275         5232022.0                        N
#
#        transaction_type_code committee_id  \
# 0                        24K    C00761528
# 1                        24K    C00761528
# 2                        24K    C00710780
# 3                        24K    C00710780
# 4                        24K    C00710780
# ...                      ...          ...
# 410509                   24K    C00125732
# 410510                   24K    C00010983
# 410511                   24K    C00010983
# 410512                   24K    C00010983
# 410513                   24K    C00010983
#
#                                             comittee_name  \
# 0                                     OREGON FRONTIER PAC
# 1                                     OREGON FRONTIER PAC
# 2                                 GRISSOM FOR U.S. SENATE
# 3                                 GRISSOM FOR U.S. SENATE
# 4                                 GRISSOM FOR U.S. SENATE
# ...                                                   ...
# 410509  BLACK HILLS CORPORATION POLITICAL ACTION COMMI...
# 410510       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
# 410511       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
# 410512       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
# 410513       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
#
#        committee_designation_code committee_type_code  \
# 0                               D                   N
# 1                               D                   N
# 2                               P                   S
# 3                               P                   S
# 4                               P                   S
# ...                           ...                 ...
# 410509                          B                   Q
# 410510                          B                   Q
# 410511                          B                   Q
# 410512                          B                   Q
# 410513                          B                   Q
#
#        connected_organization_name committee_entity_type  ...  \
# 0                            BENTZ                   CCM  ...
# 1                            BENTZ                   CCM  ...
# 2                              NaN                   CCM  ...
# 3                              NaN                   CCM  ...
# 4                              NaN                   CCM  ...
# ...                            ...                   ...  ...
# 410509                         NaN                   CCM  ...
# 410510                         NaN                   CCM  ...
# 410511                         NaN                   CCM  ...
# 410512                         NaN                   CCM  ...
# 410513                         NaN                   CCM  ...
#
#                   campaign_receipt_name candidate_id          candidate_name  \
# 0          GEORGIANS FOR KELLY LOEFFLER    S0GA00526         LOEFFLER, KELLY
# 1                     PERDUE FOR SENATE    S4GA11285           PERDUE, DAVID
# 2                   WARNOCK FOR GEORGIA    S0GA00559        WARNOCK, RAPHAEL
# 3          JAIME HARRISON FOR US SENATE    S0SC00289         HARRISON, JAIME
# 4                 JON OSSOFF FOR SENATE    S8GA00180     OSSOFF, T. JONATHAN
# ...                                 ...          ...                     ...
# 410509          MIKE FLOOD FOR CONGRESS    H2NE01118             FLOOD, MIKE
# 410510  BRIAN FITZPATRICK FOR ALL OF US    H6PA08277      FITZPATRICK, BRIAN
# 410511          CARTWRIGHT FOR CONGRESS    H2PA17079  CARTWRIGHT, MATTHEW A.
# 410512          MIKE KELLY FOR CONGRESS    H0PA03271      KELLY, GEORGE J JR
# 410513        TERRI SEWELL FOR CONGRESS    H0AL07086        SEWELL, TERRI A.
#
#        candidate_election_year  candidate_election_office_type  \
# 0                       2020.0                               S
# 1                       2022.0                               S
# 2                       2022.0                               S
# 3                       2020.0                               S
# 4                       2026.0                               S
# ...                        ...                             ...
# 410509                  2022.0                               H
# 410510                  2022.0                               H
# 410511                  2022.0                               H
# 410512                  2022.0                               H
# 410513                  2022.0                               H
#
#        candidate_state candidate_district  candidate_city candidate_zip  \
# 0                   GA                0.0         ATLANTA       30355.0
# 1                   GA                0.0         ATLANTA       30355.0
# 2                   GA                0.0         ATLANTA       30355.0
# 3                   SC                0.0        COLUMBIA       29202.0
# 4                   GA                0.0         ATLANTA       31145.0
# ...                ...                ...             ...           ...
# 410509              NE                1.0         LINCOLN       68501.0
# 410510              PA                1.0       LANGHORNE       19047.0
# 410511              PA                8.0        SCRANTON       18501.0
# 410512              PA               16.0          BUTLER       16001.0
# 410513              AL                7.0      BIRMINGHAM       35201.0
#
#         candidate_party
# 0                   REP
# 1                   REP
# 2                   DEM
# 3                   DEM
# 4                   DEM
# ...                 ...
# 410509              REP
# 410510              REP
# 410511              DEM
# 410512              REP
# 410513              DEM
#
# [410514 rows x 21 columns]

# %%
most_important_cols_df['transaction_date'] =  pd.to_datetime(most_important_cols_df['transaction_date'], format="%m%d%Y")

# %%
# Need to map the following cols:
#AMNDT_IND
#TRANSACTION_TP
#CMTE_DSGN
#CMTE_TP

# %% [markdown]
# # Mapping out codes to values

# %%
most_important_cols_df['amendment_indicator_code'].value_counts()
# Out:
# N    251879
# A    158443
# T       192
# Name: amendment_indicator_code, dtype: int64

# %% [markdown]
# 1. Amendment Indicator

# %%
amndt_ind_dict = {'N':'New','A':'Amendment','T':'Termination'}

# %% [markdown]
# 2. Transaction Type

# %%
most_important_cols_df['transaction_type_code'].value_counts()
# Out:
# 24K    383134
# 24E     23477
# 24A      3029
# 24Z       733
# 24C       100
# 24F        36
# 24R         5
# Name: transaction_type_code, dtype: int64

# %%
transaction_type_dict = {'10': 'Contribution to Independent Expenditure-Only Committees (Super PACs), Political Committees with non-contribution accounts (Hybrid PACs) and nonfederal party "soft money" accounts (1991-2002) from a person (individual, partnership, limited liability company, corporation, labor organization, or any other organization or group of persons)',
 '10J': "Memo - Recipient committee's percentage of nonfederal receipt from a person (individual, partnership, limited liability company, corporation, labor organization, or any other organization or group of persons)",
 '11': 'Native American Tribe contribution',
 '11J': "Memo - Recipient committee's percentage of contribution from Native American Tribe given to joint fundraising committee",
 '12': 'Nonfederal other receipt - Levin Account (Line 2)',
 '13': 'Inaugural donation accepted',
 '15': 'Contribution to political committees (other than Super PACs and Hybrid PACs) from an individual, partnership or limited liability company',
 '15C': 'Contribution from candidate',
 '15E': 'Earmarked contributions to political committees (other than Super PACs and Hybrid PACs) from an individual, partnership or limited liability company',
 '15F': 'Loans forgiven by candidate',
 '15I': "Earmarked contribution from an individual, partnership or limited liability company received by intermediary committee and passed on in the form of contributor's check (intermediary in)",
 '15J': "Memo - Recipient committee's percentage of contribution from an individual, partnership or limited liability company given to joint fundraising committee",
 '15T': "Earmarked contribution from an individual, partnership or limited liability company received by intermediary committee and entered into intermediary's treasury (intermediary treasury in)",
 '15Z': 'In-kind contribution received from registered filer',
 '16C': 'Loan received from the candidate',
 '16F': 'Loan received from bank',
 '16G': 'Loan from individual',
 '16H': 'Loan from registered filers',
 '16J': 'Loan repayment from individual',
 '16K': 'Loan repayment from from registered filer',
 '16L': 'Loan repayment received from unregistered entity',
 '16R': 'Loan received from registered filers',
 '16U': 'Loan received from unregistered entity',
 '17R': 'Contribution refund received from registered entity',
 '17U': 'Refund/Rebate/Return received from unregistered entity',
 '17Y': 'Refund/Rebate/Return from individual or corporation',
 '17Z': 'Refund/Rebate/Return from candidate or committee',
 '18G': 'Transfer in from affiliated committee',
 '18H': 'Honorarium received',
 '18J': "Memo - Recipient committee's percentage of contribution from a registered committee given to joint fundraising committee",
 '18K': 'Contribution received from registered filer',
 '18L': 'Bundled contribution',
 '18U': 'Contribution received from unregistered committee',
 '19': 'Electioneering communication donation received',
 '19J': "Memo - Recipient committee's percentage of Electioneering Communication donation given to joint fundraising committee",
 '20': 'Nonfederal disbursement - nonfederal party "soft money" accounts (1991-2002)',
 '20A': 'Nonfederal disbursement - Levin Account (Line 4A) Voter Registration',
 '20B': 'Nonfederal Disbursement - Levin Account (Line 4B) Voter Identification',
 '20C': 'Loan repayment made to candidate',
 '20D': 'Nonfederal disbursement - Levin Account (Line 4D) Generic Campaign',
 '20F': 'Loan repayment made to banks',
 '20G': 'Loan repayment made to individual',
 '20R': 'Loan repayment made to registered filer',
 '20V': 'Nonfederal disbursement - Levin Account (Line 4C) Get Out The Vote',
 '20Y': 'Nonfederal refund',
 '21Y': 'Native American Tribe refund',
 '22G': 'Loan to individual',
 '22H': 'Loan to candidate or committee',
 '22J': 'Loan repayment to individual',
 '22K': 'Loan repayment to candidate or committee',
 '22L': 'Loan repayment to bank',
 '22R': 'Contribution refund to unregistered entity',
 '22U': 'Loan repaid to unregistered entity',
 '22X': 'Loan made to unregistered entity',
 '22Y': 'Contribution refund to an individual, partnership or limited liability company',
 '22Z': 'Contribution refund to candidate or committee',
 '23Y': 'Inaugural donation refund',
 '24A': 'Independent expenditure opposing election of candidate',
 '24C': 'Coordinated party expenditure',
 '24E': 'Independent expenditure advocating election of candidate',
 '24F': 'Communication cost for candidate (only for Form 7 filer)',
 '24G': 'Transfer out to affiliated committee',
 '24H': 'Honorarium to candidate',
 '24I': "Earmarked contributor's check passed on by intermediary committee to intended recipient (intermediary out)",
 '24K': 'Contribution made to nonaffiliated committee',
 '24N': 'Communication cost against candidate (only for Form 7 filer)',
 '24P': 'Contribution made to possible federal candidate including in-kind contributions',
 '24R': 'Election recount disbursement',
 '24T': "Earmarked contribution passed to intended recipient from intermediary's treasury (treasury out)",
 '24U': 'Contribution made to unregistered entity',
 '24Z': 'In-kind contribution made to registered filer',
 '28L': 'Refund of bundled contribution',
 '29': 'Electioneering Communication disbursement or obligation',
 '30': 'Convention Account receipt from an individual, partnership or limited liability company',
 '30T': 'Convention Account receipt from Native American Tribe',
 '30K': 'Convention Account receipt from registered filer',
 '30G': 'Convention Account - transfer in from affiliated committee',
 '30J': "Convention Account - Memo - Recipient committee's percentage of contributions from an individual, partnership or limited liability company given to joint fundraising committee",
 '30F': "Convention Account - Memo - Recipient committee's percentage of contributions from a registered committee given to joint fundraising committee",
 '31': 'Headquarters Account receipt from an individual, partnership or limited liability company',
 '31T': 'Headquarters Account receipt from Native American Tribe',
 '31K': 'Headquarters Account receipt from registered filer',
 '31G': 'Headquarters Account - transfer in from affiliated committee',
 '31J': "Headquarters Account - Memo - Recipient committee's percentage of contributions from an individual, partnership or limited liability company given to joint fundraising committee",
 '31F': "Headquarters Account - Memo - Recipient committee's percentage of contributions from a registered committee given to joint fundraising committee",
 '32': 'Recount Account receipt from an individual, partnership or limited liability company',
 '32T': 'Recount Account receipt from Native American Tribe',
 '32K': 'Recount Account receipt from registered filer',
 '32G': 'Recount Account - transfer in from affiliated committee',
 '32J': "Recount Account - Memo - Recipient committee's percentage of contributions from an individual, partnership or limited liability company given to joint fundraising committee",
 '32F': "Recount Account - Memo - Recipient committee's percentage of contributions from a registered committee given to joint fundraising committee",
 '40': 'Convention Account disbursement',
 '40Y': 'Convention Account refund to an individual, partnership or limited liability company',
 '40T': 'Convention Account refund to Native American Tribe',
 '40Z': 'Convention Account refund to registered filer',
 '41': 'Headquarters Account disbursement',
 '41Y': 'Headquarters Account refund to an individual, partnership or limited liability company',
 '41T': 'Headquarters Account refund to Native American Tribe',
 '41Z': 'Headquarters Account refund to registered filer',
 '42': 'Recount Account disbursement',
 '42Y': 'Recount Account refund to an individual, partnership or limited liability company',
 '42T': 'Recount Account refund to Native American Tribe',
 '42Z': 'Recount Account refund to registered filer'}

# %% [markdown]
# 3. Committee Designation

# %%
most_important_cols_df['committee_designation_code'].value_counts()
# Out:
# U    297828
# B     90322
# D     17521
# P      4804
# J        37
# A         2
# Name: committee_designation_code, dtype: int64

# %%
committee_designation_dict = {'A' : 'Authorized by a candidate',
'B' : 'Lobbyist/Registrant PAC',
'D' : 'Leadership PAC',
'J' : 'Joint fundraiser',
'P' : 'Principal campaign committee of a candidate',
'U' : 'Unauthorized'}

# %% [markdown]
# 4. Committee Type

# %%
committee_type_dict = {'C': 'Communication cost',
 'D': 'Delegate committee',
 'E': 'Electioneering communication',
 'H': 'House',
 'I': 'Independent expenditor (person or group)',
 'N': 'PAC - nonqualified',
 'O': 'Independent expenditure-only (Super PACs)',
 'P': 'Presidential',
 'Q': 'PAC - qualified',
 'S': 'Senate',
 'U': 'Single-candidate independent expenditure',
 'V': 'Hybrid PAC (with Non-Contribution Account) - Nonqualified',
 'W': 'Hybrid PAC (with Non-Contribution Account) - Qualified',
 'X': 'Party - nonqualified',
 'Y': 'Party - qualified',
 'Z': 'National party nonfederal account'}

# %% [markdown]
# # Mapping all the dictionaries to the data
#
# 1. AMNDT_IND
# 2. TRANSACTION_TP
# 3. CMTE_DSGN
# 4. CMTE_TP

# %%
most_important_cols_df['amendment_indicator'] = most_important_cols_df['amendment_indicator_code']
most_important_cols_df['amendment_indicator'] = most_important_cols_df['amendment_indicator'].map(amndt_ind_dict) 

most_important_cols_df
# Out:
#           fec_record_number transaction_date amendment_indicator_code  \
# 0       4012920212139007940       2020-12-24                        N
# 1       4012920212139007941       2020-12-24                        N
# 2       4020320212018112012       2020-11-17                        T
# 3       4020320212018112003       2020-10-27                        T
# 4       4020320212018112004       2020-11-17                        T
# ...                     ...              ...                      ...
# 410509  4061720221530344955       2022-05-23                        N
# 410510  4061720221530344272       2022-05-12                        N
# 410511  4061720221530344273       2022-05-13                        N
# 410512  4061720221530344274       2022-05-13                        N
# 410513  4061720221530344275       2022-05-23                        N
#
#        transaction_type_code committee_id  \
# 0                        24K    C00761528
# 1                        24K    C00761528
# 2                        24K    C00710780
# 3                        24K    C00710780
# 4                        24K    C00710780
# ...                      ...          ...
# 410509                   24K    C00125732
# 410510                   24K    C00010983
# 410511                   24K    C00010983
# 410512                   24K    C00010983
# 410513                   24K    C00010983
#
#                                             comittee_name  \
# 0                                     OREGON FRONTIER PAC
# 1                                     OREGON FRONTIER PAC
# 2                                 GRISSOM FOR U.S. SENATE
# 3                                 GRISSOM FOR U.S. SENATE
# 4                                 GRISSOM FOR U.S. SENATE
# ...                                                   ...
# 410509  BLACK HILLS CORPORATION POLITICAL ACTION COMMI...
# 410510       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
# 410511       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
# 410512       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
# 410513       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
#
#        committee_designation_code committee_type_code  \
# 0                               D                   N
# 1                               D                   N
# 2                               P                   S
# 3                               P                   S
# 4                               P                   S
# ...                           ...                 ...
# 410509                          B                   Q
# 410510                          B                   Q
# 410511                          B                   Q
# 410512                          B                   Q
# 410513                          B                   Q
#
#        connected_organization_name committee_entity_type  ...  candidate_id  \
# 0                            BENTZ                   CCM  ...     S0GA00526
# 1                            BENTZ                   CCM  ...     S4GA11285
# 2                              NaN                   CCM  ...     S0GA00559
# 3                              NaN                   CCM  ...     S0SC00289
# 4                              NaN                   CCM  ...     S8GA00180
# ...                            ...                   ...  ...           ...
# 410509                         NaN                   CCM  ...     H2NE01118
# 410510                         NaN                   CCM  ...     H6PA08277
# 410511                         NaN                   CCM  ...     H2PA17079
# 410512                         NaN                   CCM  ...     H0PA03271
# 410513                         NaN                   CCM  ...     H0AL07086
#
#                 candidate_name candidate_election_year  \
# 0              LOEFFLER, KELLY                  2020.0
# 1                PERDUE, DAVID                  2022.0
# 2             WARNOCK, RAPHAEL                  2022.0
# 3              HARRISON, JAIME                  2020.0
# 4          OSSOFF, T. JONATHAN                  2026.0
# ...                        ...                     ...
# 410509             FLOOD, MIKE                  2022.0
# 410510      FITZPATRICK, BRIAN                  2022.0
# 410511  CARTWRIGHT, MATTHEW A.                  2022.0
# 410512      KELLY, GEORGE J JR                  2022.0
# 410513        SEWELL, TERRI A.                  2022.0
#
#        candidate_election_office_type  candidate_state candidate_district  \
# 0                                   S               GA                0.0
# 1                                   S               GA                0.0
# 2                                   S               GA                0.0
# 3                                   S               SC                0.0
# 4                                   S               GA                0.0
# ...                               ...              ...                ...
# 410509                              H               NE                1.0
# 410510                              H               PA                1.0
# 410511                              H               PA                8.0
# 410512                              H               PA               16.0
# 410513                              H               AL                7.0
#
#        candidate_city  candidate_zip candidate_party  amendment_indicator
# 0             ATLANTA        30355.0             REP                  New
# 1             ATLANTA        30355.0             REP                  New
# 2             ATLANTA        30355.0             DEM          Termination
# 3            COLUMBIA        29202.0             DEM          Termination
# 4             ATLANTA        31145.0             DEM          Termination
# ...               ...            ...             ...                  ...
# 410509        LINCOLN        68501.0             REP                  New
# 410510      LANGHORNE        19047.0             REP                  New
# 410511       SCRANTON        18501.0             DEM                  New
# 410512         BUTLER        16001.0             REP                  New
# 410513     BIRMINGHAM        35201.0             DEM                  New
#
# [410514 rows x 22 columns]

# %%
most_important_cols_df['transaction_type'] = most_important_cols_df['transaction_type_code']
most_important_cols_df['transaction_type'] = most_important_cols_df['transaction_type'].map(transaction_type_dict) 

most_important_cols_df
# Out:
#           fec_record_number transaction_date amendment_indicator_code  \
# 0       4012920212139007940       2020-12-24                        N
# 1       4012920212139007941       2020-12-24                        N
# 2       4020320212018112012       2020-11-17                        T
# 3       4020320212018112003       2020-10-27                        T
# 4       4020320212018112004       2020-11-17                        T
# ...                     ...              ...                      ...
# 410509  4061720221530344955       2022-05-23                        N
# 410510  4061720221530344272       2022-05-12                        N
# 410511  4061720221530344273       2022-05-13                        N
# 410512  4061720221530344274       2022-05-13                        N
# 410513  4061720221530344275       2022-05-23                        N
#
#        transaction_type_code committee_id  \
# 0                        24K    C00761528
# 1                        24K    C00761528
# 2                        24K    C00710780
# 3                        24K    C00710780
# 4                        24K    C00710780
# ...                      ...          ...
# 410509                   24K    C00125732
# 410510                   24K    C00010983
# 410511                   24K    C00010983
# 410512                   24K    C00010983
# 410513                   24K    C00010983
#
#                                             comittee_name  \
# 0                                     OREGON FRONTIER PAC
# 1                                     OREGON FRONTIER PAC
# 2                                 GRISSOM FOR U.S. SENATE
# 3                                 GRISSOM FOR U.S. SENATE
# 4                                 GRISSOM FOR U.S. SENATE
# ...                                                   ...
# 410509  BLACK HILLS CORPORATION POLITICAL ACTION COMMI...
# 410510       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
# 410511       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
# 410512       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
# 410513       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
#
#        committee_designation_code committee_type_code  \
# 0                               D                   N
# 1                               D                   N
# 2                               P                   S
# 3                               P                   S
# 4                               P                   S
# ...                           ...                 ...
# 410509                          B                   Q
# 410510                          B                   Q
# 410511                          B                   Q
# 410512                          B                   Q
# 410513                          B                   Q
#
#        connected_organization_name committee_entity_type  ...  \
# 0                            BENTZ                   CCM  ...
# 1                            BENTZ                   CCM  ...
# 2                              NaN                   CCM  ...
# 3                              NaN                   CCM  ...
# 4                              NaN                   CCM  ...
# ...                            ...                   ...  ...
# 410509                         NaN                   CCM  ...
# 410510                         NaN                   CCM  ...
# 410511                         NaN                   CCM  ...
# 410512                         NaN                   CCM  ...
# 410513                         NaN                   CCM  ...
#
#                 candidate_name candidate_election_year  \
# 0              LOEFFLER, KELLY                  2020.0
# 1                PERDUE, DAVID                  2022.0
# 2             WARNOCK, RAPHAEL                  2022.0
# 3              HARRISON, JAIME                  2020.0
# 4          OSSOFF, T. JONATHAN                  2026.0
# ...                        ...                     ...
# 410509             FLOOD, MIKE                  2022.0
# 410510      FITZPATRICK, BRIAN                  2022.0
# 410511  CARTWRIGHT, MATTHEW A.                  2022.0
# 410512      KELLY, GEORGE J JR                  2022.0
# 410513        SEWELL, TERRI A.                  2022.0
#
#        candidate_election_office_type candidate_state  candidate_district  \
# 0                                   S              GA                 0.0
# 1                                   S              GA                 0.0
# 2                                   S              GA                 0.0
# 3                                   S              SC                 0.0
# 4                                   S              GA                 0.0
# ...                               ...             ...                 ...
# 410509                              H              NE                 1.0
# 410510                              H              PA                 1.0
# 410511                              H              PA                 8.0
# 410512                              H              PA                16.0
# 410513                              H              AL                 7.0
#
#        candidate_city candidate_zip  candidate_party amendment_indicator  \
# 0             ATLANTA       30355.0              REP                 New
# 1             ATLANTA       30355.0              REP                 New
# 2             ATLANTA       30355.0              DEM         Termination
# 3            COLUMBIA       29202.0              DEM         Termination
# 4             ATLANTA       31145.0              DEM         Termination
# ...               ...           ...              ...                 ...
# 410509        LINCOLN       68501.0              REP                 New
# 410510      LANGHORNE       19047.0              REP                 New
# 410511       SCRANTON       18501.0              DEM                 New
# 410512         BUTLER       16001.0              REP                 New
# 410513     BIRMINGHAM       35201.0              DEM                 New
#
#                                     transaction_type
# 0       Contribution made to nonaffiliated committee
# 1       Contribution made to nonaffiliated committee
# 2       Contribution made to nonaffiliated committee
# 3       Contribution made to nonaffiliated committee
# 4       Contribution made to nonaffiliated committee
# ...                                              ...
# 410509  Contribution made to nonaffiliated committee
# 410510  Contribution made to nonaffiliated committee
# 410511  Contribution made to nonaffiliated committee
# 410512  Contribution made to nonaffiliated committee
# 410513  Contribution made to nonaffiliated committee
#
# [410514 rows x 23 columns]

# %%
most_important_cols_df['committee_designation'] = most_important_cols_df['committee_designation_code']
most_important_cols_df['committee_designation'] = most_important_cols_df['committee_designation'].map(committee_designation_dict)

# %%
most_important_cols_df['committee_type'] = most_important_cols_df['committee_type_code']
most_important_cols_df['committee_type'] = most_important_cols_df['committee_type'].map(committee_type_dict)

# %% [markdown]
# # Rearranging columns

# %%
most_important_cols_df.columns.tolist()
# Out:
# ['fec_record_number',
#  'transaction_date',
#  'amendment_indicator_code',
#  'transaction_type_code',
#  'committee_id',
#  'comittee_name',
#  'committee_designation_code',
#  'committee_type_code',
#  'connected_organization_name',
#  'committee_entity_type',
#  'transaction_amount',
#  'campaign_receipt_name',
#  'candidate_id',
#  'candidate_name',
#  'candidate_election_year',
#  'candidate_election_office_type',
#  'candidate_state',
#  'candidate_district',
#  'candidate_city',
#  'candidate_zip',
#  'candidate_party',
#  'amendment_indicator',
#  'transaction_type',
#  'committee_designation',
#  'committee_type']

# %%
columns_re_ordered_list = ['fec_record_number',
 'transaction_date',
 'amendment_indicator_code',
 'amendment_indicator',
 'transaction_type_code',
 'transaction_type',
 'committee_id',
 'comittee_name',
 'committee_designation_code',
 'committee_designation',
 'committee_type_code',
 'committee_type',
 'connected_organization_name',
 'committee_entity_type',
 'transaction_amount',
 'campaign_receipt_name',
 'candidate_id',
 'candidate_name',
 'candidate_election_year',
 'candidate_election_office_type',
 'candidate_state',
 'candidate_district',
 'candidate_city',
 'candidate_zip',
 'candidate_party']

# %%
final_df = most_important_cols_df.reindex(columns=columns_re_ordered_list)

# %%
final_df
# Out:
#           fec_record_number transaction_date amendment_indicator_code  \
# 0       4012920212139007940       2020-12-24                        N
# 1       4012920212139007941       2020-12-24                        N
# 2       4020320212018112012       2020-11-17                        T
# 3       4020320212018112003       2020-10-27                        T
# 4       4020320212018112004       2020-11-17                        T
# ...                     ...              ...                      ...
# 410509  4061720221530344955       2022-05-23                        N
# 410510  4061720221530344272       2022-05-12                        N
# 410511  4061720221530344273       2022-05-13                        N
# 410512  4061720221530344274       2022-05-13                        N
# 410513  4061720221530344275       2022-05-23                        N
#
#        amendment_indicator transaction_type_code  \
# 0                      New                   24K
# 1                      New                   24K
# 2              Termination                   24K
# 3              Termination                   24K
# 4              Termination                   24K
# ...                    ...                   ...
# 410509                 New                   24K
# 410510                 New                   24K
# 410511                 New                   24K
# 410512                 New                   24K
# 410513                 New                   24K
#
#                                     transaction_type committee_id  \
# 0       Contribution made to nonaffiliated committee    C00761528
# 1       Contribution made to nonaffiliated committee    C00761528
# 2       Contribution made to nonaffiliated committee    C00710780
# 3       Contribution made to nonaffiliated committee    C00710780
# 4       Contribution made to nonaffiliated committee    C00710780
# ...                                              ...          ...
# 410509  Contribution made to nonaffiliated committee    C00125732
# 410510  Contribution made to nonaffiliated committee    C00010983
# 410511  Contribution made to nonaffiliated committee    C00010983
# 410512  Contribution made to nonaffiliated committee    C00010983
# 410513  Contribution made to nonaffiliated committee    C00010983
#
#                                             comittee_name  \
# 0                                     OREGON FRONTIER PAC
# 1                                     OREGON FRONTIER PAC
# 2                                 GRISSOM FOR U.S. SENATE
# 3                                 GRISSOM FOR U.S. SENATE
# 4                                 GRISSOM FOR U.S. SENATE
# ...                                                   ...
# 410509  BLACK HILLS CORPORATION POLITICAL ACTION COMMI...
# 410510       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
# 410511       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
# 410512       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
# 410513       JOHNSON & JOHNSON POLITICAL ACTION COMMITTEE
#
#        committee_designation_code  \
# 0                               D
# 1                               D
# 2                               P
# 3                               P
# 4                               P
# ...                           ...
# 410509                          B
# 410510                          B
# 410511                          B
# 410512                          B
# 410513                          B
#
#                               committee_designation  ...  \
# 0                                    Leadership PAC  ...
# 1                                    Leadership PAC  ...
# 2       Principal campaign committee of a candidate  ...
# 3       Principal campaign committee of a candidate  ...
# 4       Principal campaign committee of a candidate  ...
# ...                                             ...  ...
# 410509                      Lobbyist/Registrant PAC  ...
# 410510                      Lobbyist/Registrant PAC  ...
# 410511                      Lobbyist/Registrant PAC  ...
# 410512                      Lobbyist/Registrant PAC  ...
# 410513                      Lobbyist/Registrant PAC  ...
#
#                   campaign_receipt_name candidate_id          candidate_name  \
# 0          GEORGIANS FOR KELLY LOEFFLER    S0GA00526         LOEFFLER, KELLY
# 1                     PERDUE FOR SENATE    S4GA11285           PERDUE, DAVID
# 2                   WARNOCK FOR GEORGIA    S0GA00559        WARNOCK, RAPHAEL
# 3          JAIME HARRISON FOR US SENATE    S0SC00289         HARRISON, JAIME
# 4                 JON OSSOFF FOR SENATE    S8GA00180     OSSOFF, T. JONATHAN
# ...                                 ...          ...                     ...
# 410509          MIKE FLOOD FOR CONGRESS    H2NE01118             FLOOD, MIKE
# 410510  BRIAN FITZPATRICK FOR ALL OF US    H6PA08277      FITZPATRICK, BRIAN
# 410511          CARTWRIGHT FOR CONGRESS    H2PA17079  CARTWRIGHT, MATTHEW A.
# 410512          MIKE KELLY FOR CONGRESS    H0PA03271      KELLY, GEORGE J JR
# 410513        TERRI SEWELL FOR CONGRESS    H0AL07086        SEWELL, TERRI A.
#
#        candidate_election_year  candidate_election_office_type  \
# 0                       2020.0                               S
# 1                       2022.0                               S
# 2                       2022.0                               S
# 3                       2020.0                               S
# 4                       2026.0                               S
# ...                        ...                             ...
# 410509                  2022.0                               H
# 410510                  2022.0                               H
# 410511                  2022.0                               H
# 410512                  2022.0                               H
# 410513                  2022.0                               H
#
#        candidate_state candidate_district candidate_city  candidate_zip  \
# 0                   GA                0.0        ATLANTA        30355.0
# 1                   GA                0.0        ATLANTA        30355.0
# 2                   GA                0.0        ATLANTA        30355.0
# 3                   SC                0.0       COLUMBIA        29202.0
# 4                   GA                0.0        ATLANTA        31145.0
# ...                ...                ...            ...            ...
# 410509              NE                1.0        LINCOLN        68501.0
# 410510              PA                1.0      LANGHORNE        19047.0
# 410511              PA                8.0       SCRANTON        18501.0
# 410512              PA               16.0         BUTLER        16001.0
# 410513              AL                7.0     BIRMINGHAM        35201.0
#
#        candidate_party
# 0                  REP
# 1                  REP
# 2                  DEM
# 3                  DEM
# 4                  DEM
# ...                ...
# 410509             REP
# 410510             REP
# 410511             DEM
# 410512             REP
# 410513             DEM
#
# [410514 rows x 25 columns]

# %%
final_df.to_csv("cleaned_campaign_finance.csv",index=False)
